# %% [markdown]
# ## 1. Импорт всех необходимых библиотек для работы в проекте

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_rows", None)
from sklearn.metrics import *
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

plt.rcParams["figure.dpi"] = 100
plt.style.use("ggplot")
pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda x: "{:.2f}".format(x))
pd.reset_option("display.float_format")
# from category_encoders import TargetEncoder

# Важная настройка для корректной настройки pipeline!
import sklearn

sklearn.set_config(transform_output="pandas")

# Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin

# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler,
    RobustScaler,
    MinMaxScaler,
    OrdinalEncoder,
    FunctionTransformer,
)
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.feature_selection import f_regression, chi2

# for model learning
from sklearn.model_selection import (
    train_test_split,
    RandomizedSearchCV,
    cross_val_score,
    StratifiedKFold,
)

# models
from sklearn.neighbors import (
    KNeighborsClassifier,
    RadiusNeighborsClassifier,
    KNeighborsRegressor,
)
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import (
    RandomForestClassifier,
    VotingClassifier,
    BaggingClassifier,
    RandomForestRegressor,
    VotingRegressor,
)

# LightGBM
import lightgbm as lgb

# CatBoost
from catboost import CatBoostRegressor

# Metrics
from sklearn.metrics import accuracy_score, roc_auc_score

import seaborn as sns

# tunning hyperparamters model
import optuna

# %% [markdown]
# ## 2. Обработка dataset

# %% [markdown]
# ### 2.1 Работаем c предподготовкой датасета

# %%
# Читаем датасет
main_data = pd.read_csv("./datasets/train.csv")
main_data_copy = main_data.copy().set_index("Id")
main_data_copy.drop("3SsnPorch", axis=1, inplace=True)
main_data_copy["SalePrice"] = np.log(main_data_copy["SalePrice"])

# %%
real_test = pd.read_csv("./datasets/test.csv")
real_test = real_test.copy().set_index("Id")
real_test.drop("3SsnPorch", axis=1, inplace=True)
real_test.head(3)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1461         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1462         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1463         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1461       Norm     1Fam     1Story            5            6       1961
# 1462       Norm     1Fam     1Story            6            6       1958
# 1463       Norm     1Fam     2Story            5            5       1997
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1461          1961     Gable  CompShg     VinylSd     VinylSd        NaN
# 1462          1958       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1463          1998     Gable  CompShg     VinylSd     VinylSd        NaN
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1461         0.0        TA        TA     CBlock       TA       TA
# 1462       108.0        TA        TA     CBlock       TA       TA
# 1463         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1461           No          Rec       468.0          LwQ       144.0
# 1462           No          ALQ       923.0          Unf         0.0
# 1463           No          GLQ       791.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1461      270.0        882.0    GasA        TA          Y      SBrkr
# 1462      406.0       1329.0    GasA        TA          Y      SBrkr
# 1463      137.0        928.0    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1461       896         0             0        896           0.0           0.0
# 1462      1329         0             0       1329           0.0           0.0
# 1463       928       701             0       1629           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1461         1         0             2             1          TA
# 1462         1         1             3             1          Gd
# 1463         2         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1461             5        Typ           0         NaN     Attchd       1961.0
# 1462             6        Typ           0         NaN     Attchd       1958.0
# 1463             6        Typ           1          TA     Attchd       1997.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1461          Unf         1.0       730.0         TA         TA          Y
# 1462          Unf         1.0       312.0         TA         TA          Y
# 1463          Fin         2.0       482.0         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  ScreenPorch  PoolArea PoolQC  \
# Id
# 1461         140            0              0          120         0    NaN
# 1462         393           36              0            0         0    NaN
# 1463         212           34              0            0         0    NaN
#
#       Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition
# Id
# 1461  MnPrv         NaN        0       6    2010       WD        Normal
# 1462    NaN        Gar2    12500       6    2010       WD        Normal
# 1463  MnPrv         NaN        0       3    2010       WD        Normal

# %%
def analitic_for_dataset(df):
    # делим датасет по типам данных
    df_numbers = df.select_dtypes(exclude="object")
    df_ctgrs = df.select_dtypes("object")

    # строим анализ датасета с числовыми признаками

    df_numbers_analitic = (
        pd.DataFrame(
            {
                "All_features": df_numbers.columns,
                "feature_type": df_numbers.dtypes,
                "empty_spaces": df_numbers.isna().sum(),
                "number_values": len(df_numbers),
                "unique_numbers": df_numbers.nunique(),
                "mean": df_numbers.mean(),
                "median": df_numbers.median(),
                "min": df_numbers.min(),
                "0.025": df_numbers.quantile(0.025),
                "0.975": df_numbers.quantile(0.975),
                "max": df_numbers.max(),
            }
        )
        .sort_values("unique_numbers")
        .reset_index(drop=True)
    )

    # строим анализ датасета с категориальными признаками

    modes = df_ctgrs.mode().iloc[0]

    count_mode = pd.Series(
        {col: (df_ctgrs[col] == modes[col]).sum() for col in df_ctgrs.columns}
    )

    df_ctgrs_analitic = (
        pd.DataFrame(
            {
                "All_features": df_ctgrs.columns,
                "feature_type": df_ctgrs.dtypes,
                "empty_spaces": df_ctgrs.isna().sum(),
                "number_values": len(df_ctgrs),
                "unique_numbers": df_ctgrs.nunique(),
                "mode": modes,
                "count_mode": count_mode,
            }
        )
        .sort_values("unique_numbers")
        .reset_index(drop=True)
    )

    return df_numbers_analitic, df_ctgrs_analitic, df_numbers, df_ctgrs

# %%
analitic_for_dataset(main_data_copy)[1]
# Out:
#      All_features feature_type  empty_spaces  number_values  unique_numbers  \
# 0          Street       object             0           1460               2
# 1           Alley       object          1369           1460               2
# 2      CentralAir       object             0           1460               2
# 3       Utilities       object             0           1460               2
# 4      MasVnrType       object           872           1460               3
# 5       LandSlope       object             0           1460               3
# 6          PoolQC       object          1453           1460               3
# 7      PavedDrive       object             0           1460               3
# 8    GarageFinish       object            81           1460               3
# 9        BsmtQual       object            37           1460               4
# 10      ExterQual       object             0           1460               4
# 11    KitchenQual       object             0           1460               4
# 12       BsmtCond       object            37           1460               4
# 13   BsmtExposure       object            38           1460               4
# 14          Fence       object          1179           1460               4
# 15    MiscFeature       object          1406           1460               4
# 16    LandContour       object             0           1460               4
# 17       LotShape       object             0           1460               4
# 18    FireplaceQu       object           690           1460               5
# 19     Electrical       object             1           1460               5
# 20      HeatingQC       object             0           1460               5
# 21     GarageQual       object            81           1460               5
# 22     GarageCond       object            81           1460               5
# 23       MSZoning       object             0           1460               5
# 24      LotConfig       object             0           1460               5
# 25       BldgType       object             0           1460               5
# 26      ExterCond       object             0           1460               5
# 27   BsmtFinType1       object            37           1460               6
# 28      RoofStyle       object             0           1460               6
# 29     GarageType       object            81           1460               6
# 30     Foundation       object             0           1460               6
# 31        Heating       object             0           1460               6
# 32   BsmtFinType2       object            38           1460               6
# 33  SaleCondition       object             0           1460               6
# 34     Functional       object             0           1460               7
# 35       RoofMatl       object             0           1460               8
# 36     HouseStyle       object             0           1460               8
# 37     Condition2       object             0           1460               8
# 38       SaleType       object             0           1460               9
# 39     Condition1       object             0           1460               9
# 40    Exterior1st       object             0           1460              15
# 41    Exterior2nd       object             0           1460              16
# 42   Neighborhood       object             0           1460              25
#
#        mode  count_mode
# 0      Pave        1454
# 1      Grvl          50
# 2         Y        1365
# 3    AllPub        1459
# 4   BrkFace         445
# 5       Gtl        1382
# 6        Gd           3
# 7         Y        1340
# 8       Unf         605
# 9        TA         649
# 10       TA         906
# 11       TA         735
# 12       TA        1311
# 13       No         953
# 14    MnPrv         157
# 15     Shed          49
# 16      Lvl        1311
# 17      Reg         925
# 18       Gd         380
# 19    SBrkr        1334
# 20       Ex         741
# 21       TA        1311
# 22       TA        1326
# 23       RL        1151
# 24   Inside        1052
# 25     1Fam        1220
# 26       TA        1282
# 27      Unf         430
# 28    Gable        1141
# 29   Attchd         870
# 30    PConc         647
# 31     GasA        1428
# 32      Unf        1256
# 33   Normal        1198
# 34      Typ        1360
# 35  CompShg        1434
# 36   1Story         726
# 37     Norm        1445
# 38       WD        1267
# 39     Norm        1260
# 40  VinylSd         515
# 41  VinylSd         504
# 42    NAmes         225

# %%
# где очень много пропусков у категориальных признаков, заполняем "Unknown" (фильтруем)
# collumns_nan_ctgrs = list(
#     analitic_for_dataset(main_data_copy)[3].columns[
#         (analitic_for_dataset(main_data_copy)[3].isna().sum() > 100)
#         & (analitic_for_dataset(main_data_copy)[3].isna().sum() < 1000)
#     ]
# )

column_drop_ctgrs = list(
    analitic_for_dataset(main_data_copy)[3].columns[
        analitic_for_dataset(main_data_copy)[3].isna().sum() >= 100
    ]
)
print(column_drop_ctgrs)
# Out:
# ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
# # где очень много пропусков у категориальных признаков, заполняем "Unknown" (заменяем)
# for col in collumns_nan_ctgrs:
#     main_data_copy[col] = main_data_copy[col].fillna("unknown")

# Удаляем ненужные колонки с основного датасета
main_data_copy.drop(
    column_drop_ctgrs
    + [
        "HalfBath",
        "Electrical",
        "Neighborhood",
        "BedroomAbvGr",
        "RoofStyle",
        "MSZoning",
        "GarageQual",
        "Exterior2nd",
        "LotConfig",
        "Condition2",
    ],
    inplace=True,
    axis=1,
)

# %%
# где очень много пропусков у категориальных признаков, заполняем "Unknown" (фильтруем)
# для тестовой выборки
# collumns_nan_ctgrs = list(
#     analitic_for_dataset(real_test)[3].columns[
#         (analitic_for_dataset(real_test)[3].isna().sum() > 100)
#         & (analitic_for_dataset(real_test)[3].isna().sum() < 1000)
#     ]
# )
# print((collumns_nan_ctgrs))

column_drop_ctgrs = list(
    analitic_for_dataset(real_test)[3].columns[
        analitic_for_dataset(real_test)[3].isna().sum() >= 100
    ]
)
print(column_drop_ctgrs)
# Out:
# ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
# # где очень много пропусков у категориальных признаков, заполняем "Unknown" (заменяем)
# for col in collumns_nan_ctgrs:
#     real_test[col] = real_test[col].fillna("unknown")

# Удаляем ненужные колонки из тестовой выборки
real_test.drop(
    column_drop_ctgrs
    + [
        "HalfBath",
        "Electrical",
        "Neighborhood",
        "BedroomAbvGr",
        "RoofStyle",
        "MSZoning",
        "GarageQual",
        "Exterior2nd",
        "LotConfig",
        "Condition2",
    ],
    inplace=True,
    axis=1,
)

# %% [markdown]
# ### 2.2 Готовим трансформеры для признаков(характеристик)

# %%
cutter_quants_list = [
    "LotFrontage",
    "EnclosedPorch",
    "BsmtFinSF2",
    "OpenPorchSF",
    "WoodDeckSF",
    "MasVnrArea",
    "2ndFlrSF",
    "GarageArea",
    "BsmtFinSF1",
    "TotalBsmtSF",
    "1stFlrSF",
    "BsmtUnfSF",
    "GrLivArea",
    "LotArea",
]

# %%
def cutter_quants(X):
    X_copy = X.copy()
    for col in cutter_quants_list:
        q_low = X_copy[col].quantile(0.025)
        q_high = X_copy[col].quantile(0.975)
        X_copy[col] = np.clip(X_copy[col], q_low, q_high)
    return X_copy

# %%
# Категориальные признаки 2 + (числовые итоговые)
my_inputer = ColumnTransformer(
    [
        (
            "all_num",
            SimpleImputer(strategy="median"),
            [
                "LotFrontage",
                "MasVnrArea",
                "BsmtHalfBath",
                "BsmtFullBath",
                "GarageCars",
                "GarageYrBlt",
                "BsmtFinSF2",
                "GarageArea",
                "BsmtFinSF1",
                "TotalBsmtSF",
                "BsmtUnfSF",
            ],
        ),
        (
            "all_ctgrs",
            SimpleImputer(strategy="most_frequent"),
            [
                "GarageFinish",
                "BsmtCond",
                "BsmtQual",
                "BsmtExposure",
                "GarageCond",
                "BsmtFinType1",
                "BsmtFinType2",
                "GarageType",
                "Utilities",
                "KitchenQual",
                "Functional",
                "SaleType",
                "Exterior1st",
            ],
        ),
    ],
    verbose_feature_names_out=False,
    remainder="passthrough",
)

my_cutter = ColumnTransformer(
    [("cutter", FunctionTransformer(cutter_quants), cutter_quants_list)],
    verbose_feature_names_out=False,
    remainder="passthrough",
)


ordinal = [
    "BsmtHalfBath",
    "BsmtFullBath",
    "FullBath",
    "Fireplaces",
    "KitchenAbvGr",
    "GarageCars",
    "OverallCond",
    "OverallQual",
    "MoSold",
    "TotRmsAbvGrd",
    "MSSubClass",
    "GarageYrBlt",
    "YearRemodAdd",
    "YrSold",
    "Street",
    "Utilities",
    "CentralAir",
    "LandSlope",
    "GarageFinish",
    "PavedDrive",
    "LandContour",
    "ExterQual",
    "KitchenQual",
    "BsmtQual",
    "BsmtExposure",
    "BsmtCond",
    "LotShape",
    "HeatingQC",
    "ExterCond",
    "GarageCond",
    "BldgType",
    "Heating",
    "BsmtFinType1",
    "BsmtFinType2",
    "Foundation",
    "GarageType",
    "SaleCondition",
    "Functional",
    "HouseStyle",
    "RoofMatl",
    "SaleType",
    "Condition1",
    "Exterior1st",
]

standart_sc = ["LotFrontage", "GrLivArea", "1stFlrSF", "LotArea", "YearBuilt"]

minmax = [
    "PoolArea",
    "MiscVal",
    "LowQualFinSF",
    "ScreenPorch",
    "EnclosedPorch",
    "BsmtFinSF2",
    "OpenPorchSF",
    "WoodDeckSF",
    "MasVnrArea",
    "2ndFlrSF",
    "GarageArea",
    "BsmtFinSF1",
    "TotalBsmtSF",
    "BsmtUnfSF",
]

# %%
my_scaler_and_encoder = ColumnTransformer(
    [
        (
            "ordinal",
            OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
            ordinal,
        ),
        ("standart_sc", StandardScaler(), standart_sc),
        ("minmax", MinMaxScaler(), minmax),
    ],
    verbose_feature_names_out=False,
    remainder="passthrough",
)

# %%
preprocessor = Pipeline(
    [
        ("inputering", my_inputer),
        ("cuttering", my_cutter),
        ("scaling", my_scaler_and_encoder),
    ]
)

# %%
prec_df = preprocessor.fit_transform(main_data_copy.drop("SalePrice", axis=1))

prec_df["SalePrice"] = main_data_copy["SalePrice"]

# correlation
corr_data = pd.DataFrame(
    prec_df.corr()["SalePrice"][:-1].sort_values(key=lambda x: abs(x), ascending=False)
)

# %% [raw]
# # p-value
# p_val_data = pd.Series(
#     dict(
#         zip(
#             X.columns,
#             f_regression(prec_df.drop(columns="SalePrice"), prec_df["SalePrice"])[1],
#         )
#     )
# ).sort_values()

# %% [raw]
# cr_dt = corr_data.merge(p_val_data.to_frame(name='p_value'), left_index=True, right_index=True)
#
# drop_list = cr_dt[(cr_dt['p_value'] > 0.05) & (abs(cr_dt['SalePrice']) < 0.3)].index.to_list()

# %% [raw]
# main_data_copy = main_data_copy.drop(columns=drop_list)
# real_test = real_test.drop(columns=drop_list)

# %%
plt.figure(figsize=(18, 15), dpi=200)  # увеличенный размер
sns.heatmap(prec_df.corr(), fmt=".2f", cmap="coolwarm", annot_kws={"size": 8})
# Out:
# <Axes: >

# %%
X, y = main_data_copy.drop("SalePrice", axis=True), main_data_copy["SalePrice"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=123
)

# %% [markdown]
# #### Прогоняем Optune для DecisionTreeRegressor

# %%
def objective(trial):
    # Гиперпараметры модели
    max_depth = trial.suggest_int("max_depth", 5, 15)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 7)
    criterion = trial.suggest_categorical(
        "criterion", ["squared_error", "friedman_mse", "absolute_error", "poisson"]
    )

    model = DecisionTreeRegressor(
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        criterion=criterion,
        random_state=42,
    )

    # Трансформер
    ml_pipeline = Pipeline(
        [
            ("inputering", my_inputer),
            ("cuttering", my_cutter),
            ("scaling", my_scaler_and_encoder),
            ("model", model),
        ]
    )

    trained_model = ml_pipeline.fit(X_train, y_train)
    y_test_proba = trained_model.predict(X_test)
    return root_mean_squared_error(y_test, y_test_proba)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-04 14:53:24,391] A new study created in memory with name: no-name-e3875f38-0c42-4ca0-9663-c0dc4fcdbeea
# [I 2025-07-04 14:53:24,469] Trial 0 finished with value: 0.18799591730159215 and parameters: {'max_depth': 13, 'min_samples_leaf': 4, 'criterion': 'squared_error'}. Best is trial 0 with value: 0.18799591730159215.
# [I 2025-07-04 14:53:24,675] Trial 1 finished with value: 0.191088707281479 and parameters: {'max_depth': 14, 'min_samples_leaf': 6, 'criterion': 'absolute_error'}. Best is trial 0 with value: 0.18799591730159215.
# [I 2025-07-04 14:53:24,746] Trial 2 finished with value: 0.18954466285405216 and parameters: {'max_depth': 8, 'min_samples_leaf': 3, 'criterion': 'friedman_mse'}. Best is trial 0 with value: 0.18799591730159215.
# [I 2025-07-04 14:53:24,817] Trial 3 finished with value: 0.18675801407745124 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'squared_error'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:24,885] Trial 4 finished with value: 0.18743346116022622 and parameters: {'max_depth': 13, 'min_samples_leaf': 3, 'criterion': 'friedman_mse'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:24,952] Trial 5 finished with value: 0.18824845922931374 and parameters: {'max_depth': 11, 'min_samples_leaf': 3, 'criterion': 'squared_error'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:25,144] Trial 6 finished with value: 0.18825806652855306 and parameters: {'max_depth': 8, 'min_samples_leaf': 7, 'criterion': 'absolute_error'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:25,212] Trial 7 finished with value: 0.18687816965408627 and parameters: {'max_depth': 6, 'min_samples_leaf': 3, 'criterion': 'friedman_mse'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:25,279] Trial 8 finished with value: 0.1890202465620924 and parameters: {'max_depth': 14, 'min_samples_leaf': 4, 'criterion': 'squared_error'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:25,465] Trial 9 finished with value: 0.20244902000521436 and parameters: {'max_depth': 5, 'min_samples_leaf': 5, 'criterion': 'absolute_error'}. Best is trial 3 with value: 0.18675801407745124.
# [I 2025-07-04 14:53:25,542] Trial 10 finished with value: 0.182784401887266 and parameters: {'max_depth': 11, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 10 with value: 0.182784401887266.
# [I 2025-07-04 14:53:25,614] Trial 11 finished with value: 0.18793166125777525 and parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 10 with value: 0.182784401887266.
# [I 2025-07-04 14:53:25,686] Trial 12 finished with value: 0.182784401887266 and parameters: {'max_depth': 11, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 10 with value: 0.182784401887266.
# [I 2025-07-04 14:53:25,758] Trial 13 finished with value: 0.18793166125777525 and parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 10 with value: 0.182784401887266.
# [I 2025-07-04 14:53:25,834] Trial 14 finished with value: 0.17890406355946412 and parameters: {'max_depth': 9, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 14 with value: 0.17890406355946412.
# [I 2025-07-04 14:53:25,908] Trial 15 finished with value: 0.1801284094673152 and parameters: {'max_depth': 8, 'min_samples_leaf': 5, 'criterion': 'poisson'}. Best is trial 14 with value: 0.17890406355946412.
# [I 2025-07-04 14:53:25,983] Trial 16 finished with value: 0.1801284094673152 and parameters: {'max_depth': 8, 'min_samples_leaf': 5, 'criterion': 'poisson'}. Best is trial 14 with value: 0.17890406355946412.
# [I 2025-07-04 14:53:26,056] Trial 17 finished with value: 0.17567463471171513 and parameters: {'max_depth': 7, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 17 with value: 0.17567463471171513.
# [I 2025-07-04 14:53:26,124] Trial 18 finished with value: 0.18088994709509168 and parameters: {'max_depth': 6, 'min_samples_leaf': 7, 'criterion': 'poisson'}. Best is trial 17 with value: 0.17567463471171513.
# [I 2025-07-04 14:53:26,195] Trial 19 finished with value: 0.17567463471171513 and parameters: {'max_depth': 7, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 17 with value: 0.17567463471171513.
# [I 2025-07-04 14:53:26,261] Trial 20 finished with value: 0.18268534545079876 and parameters: {'max_depth': 6, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 17 with value: 0.17567463471171513.
# [I 2025-07-04 14:53:26,331] Trial 21 finished with value: 0.1754531231321305 and parameters: {'max_depth': 9, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,397] Trial 22 finished with value: 0.17567463471171513 and parameters: {'max_depth': 7, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,463] Trial 23 finished with value: 0.17567463471171513 and parameters: {'max_depth': 7, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,534] Trial 24 finished with value: 0.1764318149573699 and parameters: {'max_depth': 9, 'min_samples_leaf': 7, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,603] Trial 25 finished with value: 0.19227709313106953 and parameters: {'max_depth': 5, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,672] Trial 26 finished with value: 0.17549750356272664 and parameters: {'max_depth': 7, 'min_samples_leaf': 7, 'criterion': 'poisson'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,924] Trial 27 finished with value: 0.1893399411194976 and parameters: {'max_depth': 9, 'min_samples_leaf': 7, 'criterion': 'absolute_error'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:26,994] Trial 28 finished with value: 0.17549750356272664 and parameters: {'max_depth': 7, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,066] Trial 29 finished with value: 0.178312203115642 and parameters: {'max_depth': 10, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,134] Trial 30 finished with value: 0.18088994709509168 and parameters: {'max_depth': 6, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,203] Trial 31 finished with value: 0.17549750356272664 and parameters: {'max_depth': 7, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,274] Trial 32 finished with value: 0.17549750356272664 and parameters: {'max_depth': 7, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,342] Trial 33 finished with value: 0.17556934624856163 and parameters: {'max_depth': 8, 'min_samples_leaf': 7, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,414] Trial 34 finished with value: 0.1754531231321305 and parameters: {'max_depth': 9, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,484] Trial 35 finished with value: 0.18218764123062373 and parameters: {'max_depth': 9, 'min_samples_leaf': 5, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,555] Trial 36 finished with value: 0.17678171899727874 and parameters: {'max_depth': 10, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,628] Trial 37 finished with value: 0.18218764123062373 and parameters: {'max_depth': 9, 'min_samples_leaf': 5, 'criterion': 'squared_error'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,699] Trial 38 finished with value: 0.17546766622971105 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,904] Trial 39 finished with value: 0.19157698234047796 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'absolute_error'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:27,979] Trial 40 finished with value: 0.18890116868344062 and parameters: {'max_depth': 15, 'min_samples_leaf': 4, 'criterion': 'squared_error'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,050] Trial 41 finished with value: 0.17546766622971105 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,123] Trial 42 finished with value: 0.17546766622971105 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,198] Trial 43 finished with value: 0.1847091077753386 and parameters: {'max_depth': 13, 'min_samples_leaf': 5, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,271] Trial 44 finished with value: 0.17546766622971105 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,343] Trial 45 finished with value: 0.18412014512857292 and parameters: {'max_depth': 12, 'min_samples_leaf': 5, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,409] Trial 46 finished with value: 0.17549899700838825 and parameters: {'max_depth': 14, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,477] Trial 47 finished with value: 0.17619563323214338 and parameters: {'max_depth': 11, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,549] Trial 48 finished with value: 0.1847091077753386 and parameters: {'max_depth': 13, 'min_samples_leaf': 5, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.
# [I 2025-07-04 14:53:28,623] Trial 49 finished with value: 0.17546766622971105 and parameters: {'max_depth': 12, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 21 with value: 0.1754531231321305.

# %%
print(study.best_params)
print(np.expm1(study.best_value) * 100)
# Out:
# {'max_depth': 9, 'min_samples_leaf': 6, 'criterion': 'poisson'}
# 19.17861201413194

# %% [raw]
# {'max_depth': 9, 'min_samples_leaf': 3, 'criterion': 'poisson'}
# 18.961168547105974

# %% [markdown]
# #### Прогоняем Optune для KNeighborsRegressor

# %%
def objective(trial):
    # Гиперпараметры модели
    n_neighbors = trial.suggest_int("n_neighbors", 1, 50)
    weights = trial.suggest_categorical("weights", ["uniform", "distance"])
    p = trial.suggest_int("p", 1, 2)
    metric = trial.suggest_categorical(
        "metric", ["minkowski", "chebyshev", "manhattan", "euclidean"]
    )

    model = KNeighborsRegressor(
        n_neighbors=n_neighbors, weights=weights, p=p, metric=metric
    )

    # Трансформер
    ml_pipeline = Pipeline(
        [
            ("inputering", my_inputer),
            ("cuttering", my_cutter),
            ("scaling", my_scaler_and_encoder),
            ("model", model),
        ]
    )

    trained_model = ml_pipeline.fit(X_train, y_train)
    y_test_proba = trained_model.predict(X_test)
    return root_mean_squared_error(y_test, y_test_proba)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-07-04 14:53:28,637] A new study created in memory with name: no-name-8c8d9a66-35d0-4966-9863-f172fbff829a
# [I 2025-07-04 14:53:28,781] Trial 0 finished with value: 0.19564520708218233 and parameters: {'n_neighbors': 39, 'weights': 'distance', 'p': 1, 'metric': 'manhattan'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:28,854] Trial 1 finished with value: 0.26440867577216026 and parameters: {'n_neighbors': 27, 'weights': 'distance', 'p': 2, 'metric': 'chebyshev'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:28,919] Trial 2 finished with value: 0.26599173425601963 and parameters: {'n_neighbors': 45, 'weights': 'distance', 'p': 1, 'metric': 'chebyshev'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:28,981] Trial 3 finished with value: 0.27241191970782225 and parameters: {'n_neighbors': 4, 'weights': 'uniform', 'p': 1, 'metric': 'chebyshev'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:29,053] Trial 4 finished with value: 0.23455088424968606 and parameters: {'n_neighbors': 35, 'weights': 'uniform', 'p': 1, 'metric': 'euclidean'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:29,140] Trial 5 finished with value: 0.2206462031481915 and parameters: {'n_neighbors': 20, 'weights': 'uniform', 'p': 2, 'metric': 'minkowski'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:29,208] Trial 6 finished with value: 0.19976460640754115 and parameters: {'n_neighbors': 36, 'weights': 'uniform', 'p': 1, 'metric': 'minkowski'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53:29,295] Trial 7 finished with value: 0.23364688818783189 and parameters: {'n_neighbors': 33, 'weights': 'uniform', 'p': 1, 'metric': 'euclidean'}. Best is trial 0 with value: 0.19564520708218233.
# [I 2025-07-04 14:53
 'weights': 'uniform', 'p': 2, 'metric': 'manhattan'}. Best is trial 25 with value: 0.17583158045884692.
# [I 2025-07-04 14:53:35,714] Trial 97 finished with value: 0.20903512780602254 and parameters: {'n_neighbors': 11, 'weights': 'uniform', 'p': 2, 'metric': 'euclidean'}. Best is trial 25 with value: 0.17583158045884692.
# [I 2025-07-04 14:53:35,781] Trial 98 finished with value: 0.17583670843246027 and parameters: {'n_neighbors': 6, 'weights': 'uniform', 'p': 2, 'metric': 'manhattan'}. Best is trial 25 with value: 0.17583158045884692.
# [I 2025-07-04 14:53:35,847] Trial 99 finished with value: 0.20634073764972446 and parameters: {'n_neighbors': 49, 'weights': 'uniform', 'p': 2, 'metric': 'manhattan'}. Best is trial 25 with value: 0.17583158045884692.

# %%
print(study.best_params)
print(np.expm1(study.best_value) * 100)
# Out:
# {'n_neighbors': 5, 'weights': 'uniform', 'p': 2, 'metric': 'manhattan'}
# 19.2237245690866

# %% [raw]
# {'n_neighbors': 13, 'weights': 'distance', 'p': 1, 'metric': 'manhattan'}
# 20.433508704420063

# %% [markdown]
# #### Прогоняем Optune для RandomForestRegressor

# %%
def objective(trial):
    # Гиперпараметры модели
    max_depth = trial.suggest_int("max_depth", 5, 15)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 7)
    criterion = trial.suggest_categorical(
        "criterion", ["squared_error", "friedman_mse", "absolute_error", "poisson"]
    )

    model = RandomForestRegressor(
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        criterion=criterion,
        random_state=42,
        n_estimators=100,
    )

    # Трансформер
    ml_pipeline = Pipeline(
        [
            ("inputering", my_inputer),
            ("cuttering", my_cutter),
            ("scaling", my_scaler_and_encoder),
            ("model", model),
        ]
    )

    trained_model = ml_pipeline.fit(X_train, y_train)
    y_test_proba = trained_model.predict(X_test)
    return root_mean_squared_error(y_test, y_test_proba)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-04 14:53:35,861] A new study created in memory with name: no-name-91b5fe13-d52e-4dac-89d1-0f4ab0909ff7
# [I 2025-07-04 14:53:36,470] Trial 0 finished with value: 0.14259224680540286 and parameters: {'max_depth': 6, 'min_samples_leaf': 4, 'criterion': 'poisson'}. Best is trial 0 with value: 0.14259224680540286.
# [I 2025-07-04 14:53:37,406] Trial 1 finished with value: 0.132283654779836 and parameters: {'max_depth': 13, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:38,247] Trial 2 finished with value: 0.13396053471684177 and parameters: {'max_depth': 13, 'min_samples_leaf': 3, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:38,921] Trial 3 finished with value: 0.13621443182429605 and parameters: {'max_depth': 9, 'min_samples_leaf': 6, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:47,367] Trial 4 finished with value: 0.1359811890845062 and parameters: {'max_depth': 13, 'min_samples_leaf': 2, 'criterion': 'absolute_error'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:47,961] Trial 5 finished with value: 0.13837092703387957 and parameters: {'max_depth': 7, 'min_samples_leaf': 6, 'criterion': 'friedman_mse'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:48,473] Trial 6 finished with value: 0.15126268635652163 and parameters: {'max_depth': 5, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:49,301] Trial 7 finished with value: 0.13399985822022395 and parameters: {'max_depth': 14, 'min_samples_leaf': 3, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:50,024] Trial 8 finished with value: 0.1354123111621565 and parameters: {'max_depth': 14, 'min_samples_leaf': 5, 'criterion': 'poisson'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:50,644] Trial 9 finished with value: 0.136530013697341 and parameters: {'max_depth': 10, 'min_samples_leaf': 7, 'criterion': 'squared_error'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:51,360] Trial 10 finished with value: 0.1345535249705769 and parameters: {'max_depth': 11, 'min_samples_leaf': 4, 'criterion': 'friedman_mse'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:52,129] Trial 11 finished with value: 0.1337950981340219 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'squared_error'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14:53:52,898] Trial 12 finished with value: 0.1337950981340219 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'squared_error'}. Best is trial 1 with value: 0.132283654779836.
# [I 2025-07-04 14
}. Best is trial 27 with value: 0.13212869384515705.
# [I 2025-07-04 14:54:42,621] Trial 46 finished with value: 0.13212869384515705 and parameters: {'max_depth': 12, 'min_samples_leaf': 2, 'criterion': 'poisson'}. Best is trial 27 with value: 0.13212869384515705.
# [I 2025-07-04 14:54:50,933] Trial 47 finished with value: 0.13624731777818833 and parameters: {'max_depth': 14, 'min_samples_leaf': 2, 'criterion': 'absolute_error'}. Best is trial 27 with value: 0.13212869384515705.
# [I 2025-07-04 14:54:51,434] Trial 48 finished with value: 0.1500274035917603 and parameters: {'max_depth': 5, 'min_samples_leaf': 5, 'criterion': 'poisson'}. Best is trial 27 with value: 0.13212869384515705.
# [I 2025-07-04 14:54:52,253] Trial 49 finished with value: 0.13370542976485097 and parameters: {'max_depth': 12, 'min_samples_leaf': 3, 'criterion': 'poisson'}. Best is trial 27 with value: 0.13212869384515705.

# %%
print(study.best_params)
print(np.expm1(study.best_value) * 100)
# Out:
# {'max_depth': 12, 'min_samples_leaf': 2, 'criterion': 'poisson'}
# 14.125518233456603

# %% [raw]
# {'max_depth': 15, 'min_samples_leaf': 2, 'criterion': 'friedman_mse'}
# 13.973698464076998

# %% [markdown]
# #### Прогоняем Optune для CatBoostRegressor

# %%
def objective(trial):
    params = {
        "iterations": 1000,
        "early_stopping_rounds": 50,
        "depth": trial.suggest_int("depth", 4, 10),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.3, log=True),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1.0, 10.0, log=True),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "random_strength": trial.suggest_float("random_strength", 1, 20),
        "grow_policy": trial.suggest_categorical(
            "grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]
        ),
        # 'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "verbose": 0,
        "loss_function": "RMSE",
        "random_state": 42,
    }

    model = CatBoostRegressor(**params)

    # Трансформер
    ml_pipeline = Pipeline(
        [
            ("inputering", my_inputer),
            ("cuttering", my_cutter),
            ("scaling", my_scaler_and_encoder),
            ("model", model),
        ]
    )

    trained_model = ml_pipeline.fit(X_train, y_train)
    y_test_proba = trained_model.predict(X_test)

    return root_mean_squared_error(y_test, y_test_proba)


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-04 14:54:52,264] A new study created in memory with name: no-name-e8ef885f-d68e-4e5d-8839-7f259e89f719
# [I 2025-07-04 14:54:54,378] Trial 0 finished with value: 0.11920548596358706 and parameters: {'depth': 8, 'learning_rate': 0.016048797965481906, 'l2_leaf_reg': 6.352957290365727, 'bagging_temperature': 0.4452311973353862, 'border_count': 255, 'random_strength': 10.291421187885925, 'grow_policy': 'SymmetricTree', 'subsample': 0.5986142840198259}. Best is trial 0 with value: 0.11920548596358706.
# [I 2025-07-04 14:54:57,035] Trial 1 finished with value: 0.11269253221564088 and parameters: {'depth': 9, 'learning_rate': 0.02894023304952539, 'l2_leaf_reg': 9.303055209742148, 'bagging_temperature': 0.42456315894915475, 'border_count': 54, 'random_strength': 13.918963772452669, 'grow_policy': 'Lossguide', 'subsample': 0.6897652202411528}. Best is trial 1 with value: 0.11269253221564088.
# [I 2025-07-04 14:55:08,481] Trial 2 finished with value: 0.1317810430164138 and parameters: {'depth': 10, 'learning_rate': 0.1179998840270941, 'l2_leaf_reg': 1.884367634354119, 'bagging_temperature': 0.9179012867568803, 'border_count': 180, 'random_strength': 19.996343064461378, 'grow_policy': 'Depthwise', 'subsample': 0.9353013434596524}. Best is trial 1 with value: 0.11269253221564088.
# [I 2025-07-04 14:55:09,636] Trial 3 finished with value: 0.132503477650655 and parameters: {'depth': 7, 'learning_rate': 0.2822278044512222, 'l2_leaf_reg': 9.704271581003027, 'bagging_temperature': 0.9630593191310118, 'border_count': 173, 'random_strength': 15.622334286931642, 'grow_policy': 'SymmetricTree', 'subsample': 0.8778645492922956}. Best is trial 1 with value: 0.11269253221564088.
# [I 2025-07-04 14:55:10,384] Trial 4 finished with value: 0.1104356638001442 and parameters: {'depth': 4, 'learning_rate': 0.01607098665599603, 'l2_leaf_reg': 1.7327597024821162, 'bagging_temperature': 0.7041356783071749, 'border_count': 66, 'random_strength': 6.463005803745367, 'grow_policy': 'Depthwise', 'subsample': 0.5208696913845986}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:12,000] Trial 5 finished with value: 0.1845730750102813 and parameters: {'depth': 5, 'learning_rate': 0.002128886963507183, 'l2_leaf_reg': 6.258783072571545, 'bagging_temperature': 0.17728553713409922, 'border_count': 74, 'random_strength': 6.4750797612606705, 'grow_policy': 'Lossguide', 'subsample': 0.9305370195911673}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:21,439] Trial 6 finished with value: 0.1298117332133168 and parameters: {'depth': 10, 'learning_rate': 0.09134562250171131, 'l2_leaf_reg': 2.6008576232983214, 'bagging_temperature': 0.4780742907981299, 'border_count': 115, 'random_strength': 13.729024334503277, 'grow_policy': 'Depthwise', 'subsample': 0.6583659591195071}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:23,022] Trial 7 finished with value: 0.11163725200493417 and parameters: {'depth': 5, 'learning_rate': 0.009448590036918735, 'l2_leaf_reg': 1.798278591111104, 'bagging_temperature': 0.7333432187450003, 'border_count': 90, 'random_strength': 2.4527911012905914, 'grow_policy': 'Depthwise', 'subsample': 0.5317655992501358}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:27,721] Trial 8 finished with value: 0.1262021432543898 and parameters: {'depth': 7, 'learning_rate': 0.09586328215335851, 'l2_leaf_reg': 1.4023001349775748, 'bagging_temperature': 0.19193487352645489, 'border_count': 242, 'random_strength': 5.597510619921251, 'grow_policy': 'Depthwise', 'subsample': 0.932132447549358}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:31,481] Trial 9 finished with value: 0.12079498678735705 and parameters: {'depth': 8, 'learning_rate': 0.05126878903387352, 'l2_leaf_reg': 7.09532907907376, 'bagging_temperature': 0.07680712946184276, 'border_count': 248, 'random_strength': 12.056550312021294, 'grow_policy': 'Lossguide', 'subsample': 0.8794570882057717}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:32,365] Trial 10 finished with value: 0.13864762978609588 and parameters: {'depth': 4, 'learning_rate': 0.003174505521682038, 'l2_leaf_reg': 1.0061891422584701, 'bagging_temperature': 0.7024291434451355, 'border_count': 32, 'random_strength': 1.8241580929921142, 'grow_policy': 'Depthwise', 'subsample': 0.5085601598679016}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:34,033] Trial 11 finished with value: 0.11259250621543447 and parameters: {'depth': 5, 'learning_rate': 0.011126019523168738, 'l2_leaf_reg': 3.0077258308400205, 'bagging_temperature': 0.7046094213148889, 'border_count': 113, 'random_strength': 1.0762376413219465, 'grow_policy': 'Depthwise', 'subsample': 0.5104260556154918}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55
. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:49,580] Trial 22 finished with value: 0.1292528376268933 and parameters: {'depth': 4, 'learning_rate': 0.007192454747540797, 'l2_leaf_reg': 1.6098346203813692, 'bagging_temperature': 0.598040369416855, 'border_count': 103, 'random_strength': 7.602595587936245, 'grow_policy': 'SymmetricTree', 'subsample': 0.8152814427154085}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:50,226] Trial 23 finished with value: 0.11345042467292511 and parameters: {'depth': 5, 'learning_rate': 0.04914829344350972, 'l2_leaf_reg': 2.700026710249385, 'bagging_temperature': 0.7406693242914117, 'border_count': 147, 'random_strength': 2.6490220186012996, 'grow_policy': 'SymmetricTree', 'subsample': 0.6201660619351879}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:50,674] Trial 24 finished with value: 0.12666948710374742 and parameters: {'depth': 4, 'learning_rate': 0.008074016682517754, 'l2_leaf_reg': 2.2001202603102685, 'bagging_temperature': 0.5251947911832997, 'border_count': 57, 'random_strength': 6.273051904184392, 'grow_policy': 'SymmetricTree', 'subsample': 0.5441777058345576}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:51,366] Trial 25 finished with value: 0.11061846168675937 and parameters: {'depth': 5, 'learning_rate': 0.0195372373253403, 'l2_leaf_reg': 1.2883115094904838, 'bagging_temperature': 0.8892607789623821, 'border_count': 179, 'random_strength': 4.289353360499201, 'grow_policy': 'SymmetricTree', 'subsample': 0.9912939936475001}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:53,037] Trial 26 finished with value: 0.11941072139998121 and parameters: {'depth': 5, 'learning_rate': 0.04140100978801248, 'l2_leaf_reg': 1.215299419215121, 'bagging_temperature': 0.8920902614062061, 'border_count': 203, 'random_strength': 9.149487765944842, 'grow_policy': 'Depthwise', 'subsample': 0.9741273561780284}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:55,629] Trial 27 finished with value: 0.11471478968443048 and parameters: {'depth': 6, 'learning_rate': 0.021096556982807345, 'l2_leaf_reg': 1.6441619265009753, 'bagging_temperature': 0.8692350149301691, 'border_count': 173, 'random_strength': 1.6014331406572158, 'grow_policy': 'Depthwise', 'subsample': 0.8244452894286313}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:57,439] Trial 28 finished with value: 0.13136347533492437 and parameters: {'depth': 5, 'learning_rate': 0.005603914698873227, 'l2_leaf_reg': 1.4228250903188404, 'bagging_temperature': 0.7437989870509447, 'border_count': 207, 'random_strength': 6.919006136468062, 'grow_policy': 'Lossguide', 'subsample': 0.5003423578932434}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:55:59,292] Trial 29 finished with value: 0.11949135650597781 and parameters: {'depth': 8, 'learning_rate': 0.016758018622866515, 'l2_leaf_reg': 1.1870274659414872, 'bagging_temperature': 0.9508052874810741, 'border_count': 191, 'random_strength': 11.075265505102678, 'grow_policy': 'SymmetricTree', 'subsample': 0.5732195611069126}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:00,651] Trial 30 finished with value: 0.11632493030839534 and parameters: {'depth': 7, 'learning_rate': 0.03825586246639185, 'l2_leaf_reg': 1.6778739739538147, 'bagging_temperature': 0.9931528933798991, 'border_count': 226, 'random_strength': 4.825042928084503, 'grow_policy': 'SymmetricTree', 'subsample': 0.8629734407268622}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:01,171] Trial 31 finished with value: 0.11193854204015534 and parameters: {'depth': 4, 'learning_rate': 0.014643455420610747, 'l2_leaf_reg': 1.8237890966518706, 'bagging_temperature': 0.7793084106267136, 'border_count': 135, 'random_strength': 4.405168022804258, 'grow_policy': 'SymmetricTree', 'subsample': 0.9877706052696855}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:01,680] Trial 32 finished with value: 0.11378955685381353 and parameters: {'depth': 4, 'learning_rate': 0.01174091924011465, 'l2_leaf_reg': 2.3812769546128676, 'bagging_temperature': 0.6318980731338435, 'border_count': 160, 'random_strength': 2.8133486316800274, 'grow_policy': 'SymmetricTree', 'subsample': 0.7240844486509764}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:02,268] Trial 33 finished with value: 0.11203599050818007 and parameters: {'depth': 5, 'learning_rate': 0.019560182740537925, 'l2_leaf_reg': 3.241681816222216, 'bagging_temperature': 0.6677807465118077, 'border_count': 100, 'random_strength': 5.217173056217224, 'grow_policy': 'SymmetricTree', 'subsample': 0.6974786311873875}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:02,700] Trial 34 finished with value: 0.11217069426629273 and parameters: {'depth': 4, 'learning_rate': 0.03510590994801416, 'l2_leaf_reg': 1.4651489578231618, 'bagging_temperature': 0.3887374960529903, 'border_count': 52, 'random_strength': 1.0098874112188878, 'grow_policy': 'SymmetricTree', 'subsample': 0.6078180798542809}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:03,354] Trial 35 finished with value: 0.1198633896029972 and parameters: {'depth': 5, 'learning_rate': 0.061930212922442, 'l2_leaf_reg': 1.9718156344948132, 'bagging_temperature': 0.854948605604384, 'border_count': 190, 'random_strength': 18.233734439610693, 'grow_policy': 'SymmetricTree', 'subsample': 0.6484922384224211}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:05,538] Trial 36 finished with value: 0.12383559856366635 and parameters: {'depth': 6, 'learning_rate': 0.17582170551602427, 'l2_leaf_reg': 1.2715866281127188, 'bagging_temperature': 0.5120254464165956, 'border_count': 72, 'random_strength': 3.436906951925611, 'grow_policy': 'Lossguide', 'subsample': 0.8103273621542437}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:13,413] Trial 37 finished with value: 0.12147994755518701 and parameters: {'depth': 9, 'learning_rate': 0.020762264646908335, 'l2_leaf_reg': 1.7833867213554384, 'bagging_temperature': 0.4546062249428259, 'border_count': 44, 'random_strength': 6.95378981668021, 'grow_policy': 'Depthwise', 'subsample': 0.9620624848272692}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:14,716] Trial 38 finished with value: 0.12118263653002433 and parameters: {'depth': 7, 'learning_rate': 0.010056625789779006, 'l2_leaf_reg': 2.748178589152267, 'bagging_temperature': 0.7751584091942225, 'border_count': 124, 'random_strength': 9.586796515374166, 'grow_policy': 'SymmetricTree', 'subsample': 0.9184668145578909}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:16,390] Trial 39 finished with value: 0.14388661120802457 and parameters: {'depth': 5, 'learning_rate': 0.0035612830331075026, 'l2_leaf_reg': 1.0145771460011068, 'bagging_temperature': 0.9251661810783305, 'border_count': 165, 'random_strength': 5.5689311155159595, 'grow_policy': 'Depthwise', 'subsample': 0.9000848281596474}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:17,487] Trial 40 finished with value: 0.11766497419987823 and parameters: {'depth': 4, 'learning_rate': 0.013985172698423165, 'l2_leaf_reg': 5.615951014484019, 'bagging_temperature': 0.6556693228124627, 'border_count': 146, 'random_strength': 13.797451748377586, 'grow_policy': 'Lossguide', 'subsample': 0.5295577892052479}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:18,006] Trial 41 finished with value: 0.11087882610711425 and parameters: {'depth': 4, 'learning_rate': 0.01569542129256725, 'l2_leaf_reg': 1.4943583776499736, 'bagging_temperature': 0.7744089863785493, 'border_count': 105, 'random_strength': 4.69704718425812, 'grow_policy': 'SymmetricTree', 'subsample': 0.9555682681138815}. Best is trial 4 with value: 0.1104356638001442.
# [I 2025-07-04 14:56:18,485] Trial 42 finished with value: 0.11028349846091236 and parameters: {'depth': 4, 'learning_rate': 0.025922462390825216, 'l2_leaf_reg': 1.5070715710299925, 'bagging_temperature': 0.7499525742910644, 'border_count': 71, 'random_strength': 6.1393642492830205, 'grow_policy': 'SymmetricTree', 'subsample': 0.9615836290985904}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:18,970] Trial 43 finished with value: 0.11272143488109837 and parameters: {'depth': 4, 'learning_rate': 0.030761556320488888, 'l2_leaf_reg': 1.4756426953136395, 'bagging_temperature': 0.8906778230753251, 'border_count': 69, 'random_strength': 6.479902837068094, 'grow_policy': 'SymmetricTree', 'subsample': 0.999972581850156}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:19,579] Trial 44 finished with value: 0.11855154861374494 and parameters: {'depth': 5, 'learning_rate': 0.0644301565933856, 'l2_leaf_reg': 1.1133628826831918, 'bagging_temperature': 0.7453227165984712, 'border_count': 84, 'random_strength': 8.330727944515328, 'grow_policy': 'SymmetricTree', 'subsample': 0.965769490632193}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:20,488] Trial 45 finished with value: 0.11488020841187793 and parameters: {'depth': 4, 'learning_rate': 0.024357048626158614, 'l2_leaf_reg': 1.3364361535436273, 'bagging_temperature': 0.6868299718936902, 'border_count': 103, 'random_strength': 5.985657157022969, 'grow_policy': 'Depthwise', 'subsample': 0.9512953037891891}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:21,073] Trial 46 finished with value: 0.12674421384711806 and parameters: {'depth': 5, 'learning_rate': 0.008432703289907922, 'l2_leaf_reg': 1.5143591033768784, 'bagging_temperature': 0.7870211480984249, 'border_count': 66, 'random_strength': 11.454152688865737, 'grow_policy': 'SymmetricTree', 'subsample': 0.9124029333995094}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:21,969] Trial 47 finished with value: 0.1126018924063125 and parameters: {'depth': 4, 'learning_rate': 0.01902931071542189, 'l2_leaf_reg': 1.820482912258594, 'bagging_temperature': 0.847736063728137, 'border_count': 92, 'random_strength': 2.959895086893458, 'grow_policy': 'Depthwise', 'subsample': 0.8642638281886137}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:33,048] Trial 48 finished with value: 0.13236766191438287 and parameters: {'depth': 10, 'learning_rate': 0.005499903336679975, 'l2_leaf_reg': 1.1639629506822164, 'bagging_temperature': 0.010748001234365145, 'border_count': 79, 'random_strength': 4.27313387299456, 'grow_policy': 'Depthwise', 'subsample': 0.9416650807921194}. Best is trial 42 with value: 0.11028349846091236.
# [I 2025-07-04 14:56:33,678] Trial 49 finished with value: 0.12092256525874187 and parameters: {'depth': 5, 'learning_rate': 0.011572115108720978, 'l2_leaf_reg': 2.399517664680523, 'bagging_temperature': 0.9298244979004636, 'border_count': 119, 'random_strength': 14.919153733320904, 'grow_policy': 'SymmetricTree', 'subsample': 0.8907119899510696}. Best is trial 42 with value: 0.11028349846091236.

# %%
print(study.best_params)
print(np.expm1(study.best_value) * 100)
# Out:
# {'depth': 4, 'learning_rate': 0.025922462390825216, 'l2_leaf_reg': 1.5070715710299925, 'bagging_temperature': 0.7499525742910644, 'border_count': 71, 'random_strength': 6.1393642492830205, 'grow_policy': 'SymmetricTree', 'subsample': 0.9615836290985904}
# 11.6594578436439

# %% [raw]
# CatBoost params:
#
# {'depth': 4, 'learning_rate': 0.02658405170681642, 'l2_leaf_reg': 1.9743324747389903, 'bagging_temperature': 0.49859192926962215, 'border_count': 178, 'random_strength': 1.9352388517796926, 'grow_policy': 'Lossguide', 'subsample': 0.9569067627252543}
# 11.522983397245428

# %% [markdown]
# #### ФИНАЛ ДЛЯ KAGGLE

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor(
    max_depth=8, min_samples_leaf=6, criterion="friedman_mse", random_state=42
)
knn = KNeighborsRegressor(n_neighbors=6, p=1, weights="distance", metric="minkowski")
rfr = RandomForestRegressor(
    n_estimators=100,
    max_depth=12,
    min_samples_leaf=2,
    criterion="poisson",
    random_state=42,
)
cb = CatBoostRegressor(
    iterations=1000,
    early_stopping_rounds=50,
    depth=5,
    learning_rate=0.034791305544360815,
    l2_leaf_reg=3.9996075411217293,
    bagging_temperature=0.693003923329511,
    border_count=53,
    random_strength=1.1760426195534421,
    grow_policy="SymmetricTree",
    subsample=0.9530745138068817,
    verbose=0,
    loss_function="RMSE",
    random_state=42,
)

# vc = VotingRegressor([("Logreg", lr), ("Dec_tree", dt), ("K_Neib", knn)])

# %%
def objective(trial):
    # Гиперпараметры модели
    raw_weights = [trial.suggest_float(f'w{i}', 0.001, 1.0) for i in range(5)]
    weight_sum = sum(raw_weights)
    weights_dirichle = [w / weight_sum for w in raw_weights]

    voting = VotingRegressor(
        estimators=[("lr", lr), ("dt", dt), ("knn", knn), ("rfr", rfr), ("cb", cb)],
        weights=weights_dirichle,
    )

    pipe = Pipeline(
        [
            ('preprocessor', preprocessor),
            ('model', voting)
        ]

    )

    trained_model = pipe.fit(X_train, y_train)
    y_pred = trained_model.predict(X_test)

    return root_mean_squared_error(y_test, y_pred)  # RMSE


study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-07-04 14:56:33,695] A new study created in memory with name: no-name-269c88fe-70ae-4e3c-ae0f-4c9d8d41fc4c
# [I 2025-07-04 14:56:35,124] Trial 0 finished with value: 0.12156602733106309 and parameters: {'w0': 0.6828112796813774, 'w1': 0.7538423650872165, 'w2': 0.41757498695421075, 'w3': 0.06054168266723839, 'w4': 0.3431487935194525}. Best is trial 0 with value: 0.12156602733106309.
# [I 2025-07-04 14:56:36,550] Trial 1 finished with value: 0.11533694595859956 and parameters: {'w0': 0.97878381826638, 'w1': 0.17755395689144088, 'w2': 0.3674399207398844, 'w3': 0.6926446080146517, 'w4': 0.3618593435441274}. Best is trial 1 with value: 0.11533694595859956.
# [I 2025-07-04 14:56:37,982] Trial 2 finished with value: 0.13391394734562975 and parameters: {'w0': 0.1440017051794141, 'w1': 0.815323915133138, 'w2': 0.6188857137833657, 'w3': 0.5218565509523764, 'w4': 0.08434386735969648}. Best is trial 1 with value: 0.11533694595859956.
# [I 2025-07-04 14:56:39,430] Trial 3 finished with value: 0.13492313998864658 and parameters: {'w0': 0.09202896078599389, 'w1': 0.4898694049065771, 'w2': 0.1861998849444295, 'w3': 0.08608622738757701, 'w4': 0.10764484693022851}. Best is trial 1 with value: 0.11533694595859956.
# [I 2025-07-04 14:56:40,882] Trial 4 finished with value: 0.1255496956985668 and parameters: {'w0': 0.41044374196168554, 'w1': 0.7898189438022513, 'w2': 0.9322749190486628, 'w3': 0.5955150896323618, 'w4': 0.4750259129840758}. Best is trial 1 with value: 0.11533694595859956.
# [I 2025-07-04 14:56:42,298] Trial 5 finished with value: 0.12372672261195662 and parameters: {'w0': 0.2524843861619152, 'w1': 0.1276777280177346, 'w2': 0.4971104660379321, 'w3': 0.5684854034779511, 'w4': 0.2072363893482833}. Best is trial 1 with value: 0.11533694595859956.
# [I 2025-07-04 14:56:43,756] Trial 6 finished with value: 0.11327747848609154 and parameters: {'w0': 0.6055213998731317, 'w1': 0.23618550647905157, 'w2': 0.29765462885761307, 'w3': 0.5402283437153328, 'w4': 0.9325607440575956}. Best is trial 6 with value: 0.11327747848609154.
# [I 2025-07-04 14:56:45,196] Trial 7 finished with value: 0.12219683439360388 and parameters: {'w0': 0.15063387421989172, 'w1': 0.5157039928486231, 'w2': 0.7084292406335556, 'w3': 0.11995257285796773, 'w4': 0.8253048369677852}. Best is trial 6 with value: 0.11327747848609154.
# [I 2025-07-04 14:56:46,677] Trial 8 finished with value: 0.11083990345218471 and parameters: {'w0': 0.7506033303221112, 'w1': 0.17983481814642419, 'w2': 0.17479708168242075, 'w3': 0.35808522896200756, 'w4': 0.9944378743790732}. Best is trial 8 with value: 0.11083990345218471.
# [I 2025-07-04 14:56:48,130] Trial 9 finished with value: 0.11864114413578104 and parameters: {'w0': 0.8324974596620418, 'w1': 0.8735117704808394, 'w2': 0.4674656966250517, 'w3': 0.31775170321149676, 'w4': 0.7399598452218079}. Best is trial 8 with value: 0.11083990345218471.
# [I 2025-07-04 14:56:49,596] Trial 10 finished with value: 0.1175914669792238 and parameters: {'w0': 0.44317799443863864, 'w1': 0.3789948655744543, 'w2': 0.016393134003278215, 'w3': 0.8917583329069475, 'w4': 0.6363134429375936}. Best is trial 8 with value: 0.11083990345218471.
# [I 2025-07-04 14:56:51,057] Trial 11 finished with value: 0.11034144698461316 and parameters: {'w0': 0.6566363104135474, 'w1': 0.03762408618796942, 'w2': 0.18965947278410708, 'w3': 0.34470635093354823, 'w4': 0.994437858601342}. Best is trial 11 with value: 0.11034144698461316.
# [I 2025-07-04 14:56:52,525] Trial 12 finished with value: 0.10924306425593651 and parameters: {'w0': 0.766295698094956, 'w1': 0.02288129217040752, 'w2': 0.06981824799806367, 'w3': 0.309548234894284, 'w4': 0.9991912872753306}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14
. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:35,819] Trial 42 finished with value: 0.10980542082959018 and parameters: {'w0': 0.9452637885804824, 'w1': 0.07768399579718711, 'w2': 0.054222869599881714, 'w3': 0.04300517559205811, 'w4': 0.5838073766515222}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:37,253] Trial 43 finished with value: 0.10998618732155716 and parameters: {'w0': 0.88888949451736, 'w1': 0.05162708811061663, 'w2': 0.09863361467387594, 'w3': 0.12916627029585365, 'w4': 0.602298135575735}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:38,763] Trial 44 finished with value: 0.1100906086888217 and parameters: {'w0': 0.8315036193416055, 'w1': 0.13656313924671465, 'w2': 0.0016510193362038184, 'w3': 0.00590625042071099, 'w4': 0.4832433299596911}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:40,151] Trial 45 finished with value: 0.11300944226696112 and parameters: {'w0': 0.7068130984733972, 'w1': 0.20302323694294808, 'w2': 0.19605005424172967, 'w3': 0.38013498869596113, 'w4': 0.5378348531195736}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:41,601] Trial 46 finished with value: 0.11164926219063426 and parameters: {'w0': 0.9491279726702873, 'w1': 0.29061728739814635, 'w2': 0.05574150982822247, 'w3': 0.3245459219360402, 'w4': 0.7078487281193203}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:43,011] Trial 47 finished with value: 0.11006563009476375 and parameters: {'w0': 0.760920167623836, 'w1': 0.0036028831774289616, 'w2': 0.15399462834600655, 'w3': 0.0843014034305461, 'w4': 0.6403391219641345}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:44,455] Trial 48 finished with value: 0.11733912430748665 and parameters: {'w0': 0.848262371045932, 'w1': 0.3892911816354776, 'w2': 0.7716599870452983, 'w3': 0.629169756054677, 'w4': 0.8063884572255171}. Best is trial 12 with value: 0.10924306425593651.
# [I 2025-07-04 14:57:45,864] Trial 49 finished with value: 0.11307410503425017 and parameters: {'w0': 0.44595034360278174, 'w1': 0.102312456902854, 'w2': 0.10375960622820357, 'w3': 0.49533068386397716, 'w4': 0.5223595387637098}. Best is trial 12 with value: 0.10924306425593651.

# %%
print(study.best_params)
print(np.expm1(study.best_value) * 100)
# Out:
# {'w0': 0.766295698094956, 'w1': 0.02288129217040752, 'w2': 0.06981824799806367, 'w3': 0.309548234894284, 'w4': 0.9991912872753306}
# 11.543343939307661

# %% [raw]
# {'w0': 0.744007544490073, 'w1': 0.036821482733168646, 'w2': 0.04938543280075221, 'w3': 0.08451613445303022, 'w4': 0.9988328004130205}
# 11.451226959421987

# %%
voting = VotingRegressor(
        estimators=[("lr", lr), ("dt", dt), ("knn", knn), ("rfr", rfr), ("cb", cb)],
        weights=[0.744007544490073, 0.036821482733168646, 0.04938543280075221, 0.08451613445303022, 0.9988328004130205],
    )

pipe = Pipeline(
    [
        ('preprocessor', preprocessor),
        ('model', voting)
    ]
)

# %%
final_model = pipe.fit(X_train, y_train)

# %%
y_final = final_model.predict(real_test)
np.exp(y_final)
# Out:
# array([121607.1780396 , 157662.20075959, 181665.86391716, ...,
#        165477.44338375, 121093.26511239, 241325.11726176], shape=(1459,))

# %%
final_csv = pd.DataFrame(np.exp(y_final), real_test.index).reset_index()
final_csv.columns = ["Id", "SalePrice"]
final_csv.to_csv("submission3.csv", index=False)
